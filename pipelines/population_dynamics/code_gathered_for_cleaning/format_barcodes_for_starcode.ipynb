# %% [markdown]
# # Title

# %% [markdown]
# # Introduction

# %% [markdown]
# State notebook purpose here.

# %% [markdown]
# ## Imports

# %%
import sys
import os
import time
import copy
import random
import math
import itertools

import numpy as np
import scipy
import pandas as pd

# Set pandas display options
pd.set_option('display.max_rows', 30)
pd.set_option('display.max_columns', 100)
pd.set_option('display.width', 1000)

# %matplotlib inline
from matplotlib import pyplot as plt
import matplotlib as mpl
import seaborn as sns

# Set plot display options
params = {
    'font.size': 12,
    'axes.titlesize': 12,
    'axes.labelsize': 12,
    'legend.fontsize': 12,
    'xtick.labelsize': 12,
    'ytick.labelsize': 12,
    'font.family': "Helvetica",
    'pdf.fonttype': 42,
    'ps.fonttype': 42,
    'figure.dpi': 300
   }
mpl.rcParams.update(params)
sns.set_style("ticks", {'axes.grid' : False})

# Set plot output options
output_dir = "outs/"
output_suffix = ""
output_formats = [".png", ".pdf"]

mpl.rc('savefig', dpi=300)

# Define convenience function for saving figures

savefig = True
savefig_args = {"dpi": 300, "bbox_inches": "tight", "pad_inches": 0}

def save_figure(fig, name, output_dir=output_dir, output_suffix=output_suffix, output_formats=output_formats, savefig_args=savefig_args):
    if savefig:
        for output_format in output_formats:
            fig.savefig(output_dir + "/" + name + output_suffix + output_format, **savefig_args)
    return None

# %%
# import additional libraries and settings here

# %% [markdown]
# # Load data

# %% [markdown]
# State data here.

# %%
# %%time

infile = "/scratch/CellFreeReporter/analysis/Demo6/clones.tsv.gz"

counts_raw = pd.read_csv(infile, sep="\t", compression="gzip")

print(counts_raw.shape)
counts_raw.head()
# Out:
# (5453959, 4)
# CPU times: user 4.87 s, sys: 527 ms, total: 5.4 s
# Wall time: 5.4 s
#        lib library_barcode_call                clone_barcode  count
# 0  sFH11-1                  LB1  AGACAGTGTGACAGTGTGTGACTCTGA    552
# 1  sFH11-1                  LB1  TGAGAGTGTCTGACTCAGTCTCTGTGT    510
# 2  sFH11-1                  LB1  AGAGTCTGACTCACTCAGTGTCTGTCT    465
# 3  sFH11-1                  LB1  TGTCTGAGTCTGTCTGTGTCACTGTCT    461
# 4  sFH11-1                  LB1  ACTGTCTGTCAGACACTCTGTCACTCT    440

# %% [markdown]
# # Preprocess barcodes

# %% [markdown]
# ## Filter for library barcodes of interest (LB1, LB2)

# %%
library_barcode_calls_to_keep = ["LB1", "LB2"]

counts = counts_raw.set_index(["lib", "library_barcode_call", "clone_barcode"])

counts = counts.loc[:, library_barcode_calls_to_keep, :]

counts
# Out:
#                                                           count
# lib     library_barcode_call clone_barcode
# sFH11-1 LB1                  AGACAGTGTGACAGTGTGTGACTCTGA    552
#                              TGAGAGTGTCTGACTCAGTCTCTGTGT    510
#                              AGAGTCTGACTCACTCAGTGTCTGTCT    465
#                              TGTCTGAGTCTGTCTGTGTCACTGTCT    461
#                              ACTGTCTGTCAGACACTCTGTCACTCT    440
# ...                                                         ...
# sFH12-9 LB2                  TTGGAGAGGCAGTGAGACAGTGAGAGT      1
#                              TTTCAGTGAGACTCAGTCTGTGTGAGA      1
#                              TTTCTGTGTGTCTCTCTCAGAGTGTGA      1
#                              TTTGAGACTCACAGTCTGACTCACTGT      1
#                              TTTGGGAGTAGGTATCTGGGTGAGTCT      1
#
# [5434262 rows x 1 columns]

# %% [markdown]
# ## Reset index

# %%
counts = counts.reset_index()

# %%
counts
# Out:
#              lib library_barcode_call                clone_barcode  count
# 0        sFH11-1                  LB1  AGACAGTGTGACAGTGTGTGACTCTGA    552
# 1        sFH11-1                  LB1  TGAGAGTGTCTGACTCAGTCTCTGTGT    510
# 2        sFH11-1                  LB1  AGAGTCTGACTCACTCAGTGTCTGTCT    465
# 3        sFH11-1                  LB1  TGTCTGAGTCTGTCTGTGTCACTGTCT    461
# 4        sFH11-1                  LB1  ACTGTCTGTCAGACACTCTGTCACTCT    440
# ...          ...                  ...                          ...    ...
# 5434257  sFH12-9                  LB2  TTGGAGAGGCAGTGAGACAGTGAGAGT      1
# 5434258  sFH12-9                  LB2  TTTCAGTGAGACTCAGTCTGTGTGAGA      1
# 5434259  sFH12-9                  LB2  TTTCTGTGTGTCTCTCTCAGAGTGTGA      1
# 5434260  sFH12-9                  LB2  TTTGAGACTCACAGTCTGACTCACTGT      1
# 5434261  sFH12-9                  LB2  TTTGGGAGTAGGTATCTGGGTGAGTCT      1
#
# [5434262 rows x 4 columns]

# %% [markdown]
# # Export clone barcodes in format for Starcode

# %%
# Report number of barcodes per group

for (lib, library_barcode_call), group in counts.groupby(["lib", "library_barcode_call"]):
    
    print(lib, "\t", library_barcode_call, "\t", group.shape[0])
# Out:
# sFH11-1 	 LB1 	 11335
# sFH11-1 	 LB2 	 33614
# sFH11-10 	 LB1 	 5132
# sFH11-10 	 LB2 	 129428
# sFH11-11 	 LB1 	 5372
# sFH11-11 	 LB2 	 85094
# sFH11-12 	 LB1 	 1598
# sFH11-12 	 LB2 	 75038
# sFH11-13 	 LB1 	 2237
# sFH11-13 	 LB2 	 58917
# sFH11-14 	 LB1 	 3965
# sFH11-14 	 LB2 	 208115
# sFH11-15 	 LB1 	 10519
# sFH11-15 	 LB2 	 28189
# sFH11-16 	 LB1 	 15736
# sFH11-16 	 LB2 	 59740
# sFH11-17 	 LB1 	 38371
# sFH11-17 	 LB2 	 110290
# sFH11-18 	 LB1 	 55247
# sFH11-18 	 LB2 	 141169
# sFH11-19 	 LB1 	 60502
# sFH11-19 	 LB2 	 146507
# sFH11-2 	 LB1 	 25140
# sFH11-2 	 LB2 	 33076
# sFH11-20 	 LB1 	 71045
# sFH11-20 	 LB2 	 159611
# sFH11-21 	 LB1 	 115970
# sFH11-21 	 LB2 	 251097
# sFH11-3 	 LB1 	 28975
# sFH11-3 	 LB2 	 11400
# sFH11-4 	 LB1 	 24809
# sFH11-4 	 LB2 	 4650
# sFH11-5 	 LB1 	 43649
# sFH11-5 	 LB2 	 6528
# sFH11-6 	 LB1 	 54976
# sFH11-6 	 LB2 	 9517
# sFH11-7 	 LB1 	 52979
# sFH11-7 	 LB2 	 2970
# sFH11-8 	 LB1 	 14733
# sFH11-8 	 LB2 	 32846
# sFH11-9 	 LB1 	 3113
# sFH11-9 	 LB2 	 66813
# sFH12-10 	 LB1 	 448755
# sFH12-10 	 LB2 	 14870
# sFH12-11 	 LB1 	 20112
# sFH12-11 	 LB2 	 260549
# sFH12-12 	 LB1 	 27614
# sFH12-12 	 LB2 	 224696
# sFH12-13 	 LB1 	 474246
# sFH12-13 	 LB2 	 230421
# sFH12-14 	 LB1 	 526139
# sFH12-14 	 LB2 	 268952
# sFH12-9 	 LB1 	 618962
# sFH12-9 	 LB2 	 18934

# %%
# %%time

output_dir = "/scratch/CellFreeReporter/pipelines/220520_Demo6_consensus_error_correct_starcode/"

for (lib, library_barcode_call), group in counts.groupby(["lib", "library_barcode_call"]):

    outfile = output_dir + "/" + "clone_barcodes." + lib + "." + library_barcode_call + ".tsv.tmp"
    
    group_clean = group[["clone_barcode", "count"]]
    
    print(lib, "\t", library_barcode_call, "\t", group.shape[0])
    print("Writing... " + outfile)
    
    group_clean.to_csv(outfile, sep="\t", index=False, header=False)

    print("Done!")
    print()
# Out:
# sFH11-1 	 LB1 	 11335
# Writing... /scratch/CellFreeReporter/pipelines/220520_Demo6_consensus_error_correct_starcode//clone_barcodes.sFH11-1.LB1.tsv.tmp
# Done!
#
# sFH11-1 	 LB2 	 33614
# Writing... /scratch/CellFreeReporter/pipelines/220520_Demo6_consensus_error_correct_starcode//clone_barcodes.sFH11-1.LB2.tsv.tmp
# Done!
#
# sFH11-10 	 LB1 	 5132
# Writing... /scratch/CellFreeReporter/pipelines/220520_Demo6_consensus_error_correct_starcode//clone_barcodes.sFH11-10.LB1.tsv.tmp
# Done!
#
# sFH11-10 	 LB2 	 129428
# Writing... /scratch/CellFreeReporter/pipelines/220520_Demo6_consensus_error_correct_starcode//clone_barcodes.sFH11-10.LB2.tsv.tmp
# Done!
#
# sFH11-11 	 LB1 	 5372
# Writing... /scratch/CellFreeReporter/pipelines/220520_Demo6_consensus_error_correct_starcode//clone_barcodes.sFH11-11.LB1.tsv.tmp
# Done!
#
# sFH11-11 	 LB2 	 85094
# Writing... /scratch/CellFreeReporter/pipelines/220520_Demo6_consensus_error_correct_starcode//clone_barcodes.sFH11-11.LB2.tsv.tmp
# Done!
#
# sFH11-12 	 LB1 	 1598
# Writing... /scratch/CellFreeReporter/pipelines/220520_Demo6_consensus_error_correct_starcode//clone_barcodes.sFH11-12.LB1.tsv.tmp
# Done!
#
# sFH11-12 	 LB2 	 75038
# Writing... /scratch/CellFreeReporter/pipelines/220520_Demo6_consensus_error_correct_starcode//clone_barcodes.sFH11-12.LB2.tsv.tmp
# Done!
#
# sFH11-13 	 LB1 	 2237
# Writing... /scratch/CellFreeReporter/pipelines/220520_Demo6_consensus_error_correct_starcode//clone_barcodes.sFH11-13.LB1.tsv.tmp
# Done!
#
# sFH11-13 	 LB2 	 58917
# Writing... /scratch/CellFreeReporter/pipelines/220520_Demo6_consensus_error_correct_starcode//clone_barcodes.sFH11-13.LB2.tsv.tmp
# Done!
#
# sFH11-14 	 LB1 	 3965
# Writing... /scratch/CellFreeReporter/pipelines/220520_Demo6_consensus_error_correct_starcode//clone_barcodes.sFH11-14.LB1.tsv.tmp
# Done!
#
# sFH11-14 	 LB2 	 208115
# Writing... /scratch/CellFreeReporter/pipelines/220520_Demo6_consensus_error_correct_starcode//clone_barcodes.sFH11-14.LB2.tsv.tmp
# Done!
#
# sFH11-15 	 LB1 	 10519
# Writing... /scratch/CellFreeReporter/pipelines/220520_Demo6_consensus_error_correct_starcode//clone_barcodes.sFH11-15.LB1.tsv.tmp
# Done!
#
# sFH11-15 	 LB2 	 28189
# Writing... /scratch/CellFreeReporter/pipelines/220520_Demo6_consensus_error_correct_starcode//clone_barcodes.sFH11-15.LB2.tsv.tmp
# Done!
#
# sFH11-16 	 LB1 	 15736
# Writing... /scratch/CellFreeReporter/pipelines/220520_Demo6_consensus_error_correct_starcode//clone_barcodes.sFH11-16.LB1.tsv.tmp
# Done!
#
# sFH11-16 	 LB2 	 59740
# Writing... /scratch/CellFreeReporter/pipelines/220520_Demo6_consensus_error_correct_starcode//clone_barcodes.sFH11-16.LB2.tsv.tmp
# Done!
#
# sFH11-17 	 LB1 	 38371
# Writing... /scratch/CellFreeReporter/pipelines/220520_Demo6_consensus_error_correct_starcode//clone_barcodes.sFH11-17.LB1.tsv.tmp
# Done!
#
# sFH11-17 	 LB2 	 110290
# Writing... /scratch/CellFreeReporter/pipelines/220520_Demo6_consensus_error_correct_starcode//clone_barcodes.sFH11-17.LB2.tsv.tmp
# Done!
#
# sFH11-18 	 LB1 	 55247
# Writing... /scratch/CellFreeReporter/pipelines/220520_Demo6_consensus_error_correct_starcode//clone_barcodes.sFH11-18.LB1.tsv.tmp
# Done!
#
# sFH11-18 	 LB2 	 141169
# Writing... /scratch/CellFreeReporter/pipelines/220520_Demo6_consensus_error_correct_starcode//clone_barcodes.sFH11-18.LB2.tsv.tmp
# Done!
#
# sFH11-19 	 LB1 	 60502
# Writing... /scratch/CellFreeReporter/pipelines/220520_Demo6_consensus_error_correct_starcode//clone_barcodes.sFH11-19.LB1.tsv.tmp
# Done!
#
# sFH11-19 	 LB2 	 146507
# Writing... /scratch/CellFreeReporter/pipelines/220520_Demo6_consensus_error_correct_starcode//clone_barcodes.sFH11-19.LB2.tsv.tmp
# Done!
#
# sFH11-2 	 LB1 	 25140
# Writing... /scratch/CellFreeReporter/pipelines/220520_Demo6_consensus_error_correct_starcode//clone_barcodes.sFH11-2.LB1.tsv.tmp
# Done!
#
# sFH11-2 	 LB2 	 33076
# Writing... /scratch/CellFreeReporter/pipelines/220520_Demo6_consensus_error_correct_starcode//clone_barcodes.sFH11-2.LB2.tsv.tmp
# Done!
#
# sFH11-20 	 LB1 	 71045
# Writing... /scratch/CellFreeReporter/pipelines/220520_Demo6_consensus_error_correct_starcode//clone_barcodes.sFH11-20.LB1.tsv.tmp
# Done!
#
# sFH11-20 	 LB2 	 159611
# Writing... /scratch/CellFreeReporter/pipelines/220520_Demo6_consensus_error_correct_starcode//clone_barcodes.sFH11-20.LB2.tsv.tmp
# Done!
#
# sFH11-21 	 LB1 	 115970
# Writing... /scratch/CellFreeReporter/pipelines/220520_Demo6_consensus_error_correct_starcode//clone_barcodes.sFH11-21.LB1.tsv.tmp
# Done!
#
# sFH11-21 	 LB2 	 251097
# Writing... /scratch/CellFreeReporter/pipelines/220520_Demo6_consensus_error_correct_starcode//clone_barcodes.sFH11-21.LB2.tsv.tmp
# Done!
#
# sFH11-3 	 LB1 	 28975
# Writing... /scratch/CellFreeReporter/pipelines/220520_Demo6_consensus_error_correct_starcode//clone_barcodes.sFH11-3.LB1.tsv.tmp
# Done!
#
# sFH11-3 	 LB2 	 11400
# Writing... /scratch/CellFreeReporter/pipelines/220520_Demo6_consensus_error_correct_starcode//clone_barcodes.sFH11-3.LB2.tsv.tmp
# Done!
#
# sFH11-4 	 LB1 	 24809
# Writing... /scratch/CellFreeReporter/pipelines/220520_Demo6_consensus_error_correct_starcode//clone_barcodes.sFH11-4.LB1.tsv.tmp
# Done!
#
# sFH11-4 	 LB2 	 4650
# Writing... /scratch/CellFreeReporter/pipelines/220520_Demo6_consensus_error_correct_starcode//clone_barcodes.sFH11-4.LB2.tsv.tmp
# Done!
#
# sFH11-5 	 LB1 	 43649
# Writing... /scratch/CellFreeReporter/pipelines/220520_Demo6_consensus_error_correct_starcode//clone_barcodes.sFH11-5.LB1.tsv.tmp
# Done!
#
# sFH11-5 	 LB2 	 6528
# Writing... /scratch/CellFreeReporter/pipelines/220520_Demo6_consensus_error_correct_starcode//clone_barcodes.sFH11-5.LB2.tsv.tmp
# Done!
#
# sFH11-6 	 LB1 	 54976
# Writing... /scratch/CellFreeReporter/pipelines/220520_Demo6_consensus_error_correct_starcode//clone_barcodes.sFH11-6.LB1.tsv.tmp
# Done!
#
# sFH11-6 	 LB2 	 9517
# Writing... /scratch/CellFreeReporter/pipelines/220520_Demo6_consensus_error_correct_starcode//clone_barcodes.sFH11-6.LB2.tsv.tmp
# Done!
#
# sFH11-7 	 LB1 	 52979
# Writing... /scratch/CellFreeReporter/pipelines/220520_Demo6_consensus_error_correct_starcode//clone_barcodes.sFH11-7.LB1.tsv.tmp
# Done!
#
# sFH11-7 	 LB2 	 2970
# Writing... /scratch/CellFreeReporter/pipelines/220520_Demo6_consensus_error_correct_starcode//clone_barcodes.sFH11-7.LB2.tsv.tmp
# Done!
#
# sFH11-8 	 LB1 	 14733
# Writing... /scratch/CellFreeReporter/pipelines/220520_Demo6_consensus_error_correct_starcode//clone_barcodes.sFH11-8.LB1.tsv.tmp
# Done!
#
# sFH11-8 	 LB2 	 32846
# Writing... /scratch/CellFreeReporter/pipelines/220520_Demo6_consensus_error_correct_starcode//clone_barcodes.sFH11-8.LB2.tsv.tmp
# Done!
#
# sFH11-9 	 LB1 	 3113
# Writing... /scratch/CellFreeReporter/pipelines/220520_Demo6_consensus_error_correct_starcode//clone_barcodes.sFH11-9.LB1.tsv.tmp
# Done!
#
# sFH11-9 	 LB2 	 66813
# Writing... /scratch/CellFreeReporter/pipelines/220520_Demo6_consensus_error_correct_starcode//clone_barcodes.sFH11-9.LB2.tsv.tmp
# Done!
#
# sFH12-10 	 LB1 	 448755
# Writing... /scratch/CellFreeReporter/pipelines/220520_Demo6_consensus_error_correct_starcode//clone_barcodes.sFH12-10.LB1.tsv.tmp
# Done!
#
# sFH12-10 	 LB2 	 14870
# Writing... /scratch/CellFreeReporter/pipelines/220520_Demo6_consensus_error_correct_starcode//clone_barcodes.sFH12-10.LB2.tsv.tmp
# Done!
#
# sFH12-11 	 LB1 	 20112
# Writing... /scratch/CellFreeReporter/pipelines/220520_Demo6_consensus_error_correct_starcode//clone_barcodes.sFH12-11.LB1.tsv.tmp
# Done!
#
# sFH12-11 	 LB2 	 260549
# Writing... /scratch/CellFreeReporter/pipelines/220520_Demo6_consensus_error_correct_starcode//clone_barcodes.sFH12-11.LB2.tsv.tmp
# Done!
#
# sFH12-12 	 LB1 	 27614
# Writing... /scratch/CellFreeReporter/pipelines/220520_Demo6_consensus_error_correct_starcode//clone_barcodes.sFH12-12.LB1.tsv.tmp
# Done!
#
# sFH12-12 	 LB2 	 224696
# Writing... /scratch/CellFreeReporter/pipelines/220520_Demo6_consensus_error_correct_starcode//clone_barcodes.sFH12-12.LB2.tsv.tmp
# Done!
#
# sFH12-13 	 LB1 	 474246
# Writing... /scratch/CellFreeReporter/pipelines/220520_Demo6_consensus_error_correct_starcode//clone_barcodes.sFH12-13.LB1.tsv.tmp
# Done!
#
# sFH12-13 	 LB2 	 230421
# Writing... /scratch/CellFreeReporter/pipelines/220520_Demo6_consensus_error_correct_starcode//clone_barcodes.sFH12-13.LB2.tsv.tmp
# Done!
#
# sFH12-14 	 LB1 	 526139
# Writing... /scratch/CellFreeReporter/pipelines/220520_Demo6_consensus_error_correct_starcode//clone_barcodes.sFH12-14.LB1.tsv.tmp
# Done!
#
# sFH12-14 	 LB2 	 268952
# Writing... /scratch/CellFreeReporter/pipelines/220520_Demo6_consensus_error_correct_starcode//clone_barcodes.sFH12-14.LB2.tsv.tmp
# Done!
#
# sFH12-9 	 LB1 	 618962
# Writing... /scratch/CellFreeReporter/pipelines/220520_Demo6_consensus_error_correct_starcode//clone_barcodes.sFH12-9.LB1.tsv.tmp
# Done!
#
# sFH12-9 	 LB2 	 18934
# Writing... /scratch/CellFreeReporter/pipelines/220520_Demo6_consensus_error_correct_starcode//clone_barcodes.sFH12-9.LB2.tsv.tmp
# Done!
#
# CPU times: user 9.82 s, sys: 744 ms, total: 10.6 s
# Wall time: 11.1 s

# %% [markdown]
# Next step is running starcode on these barcodes using `starcode.sh`
